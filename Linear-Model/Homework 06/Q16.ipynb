# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_excel('Q16.xlsx')
data.head()
# Out:
#    Year  Mortality_Rate
# 0  1915        0.521505
# 1  1916        0.424828
# 2  1917        0.425031
# 3  1918        0.477194
# 4  1919        0.828021

# %%
plt.title("Time Series for Mortality Rate")
sns.lineplot(x="Year", y="Mortality_Rate", data=data,color='red')
plt.savefig("Time Series for Mortality Rate.png")
plt.show()
