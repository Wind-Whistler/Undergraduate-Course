# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('Q3.xlsx')
data.head()
# Out:
#    Month  Rainfall
# 0      1      69.3
# 1      2      80.0
# 2      3      40.9
# 3      4      74.9
# 4      5      84.6

# %%
plt.figure(figsize=(10,6))
plt.title('Time Series of Rainfall')
sns.lineplot(x=data['Month'],y=data['Rainfall'],color='red')
plt.savefig('Time Series of Rainfall.png')
plt.show()
