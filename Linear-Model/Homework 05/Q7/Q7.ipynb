# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('Q7.xlsx')
data.head()
# Out:
#    Year  Mortality Rate
# 0  1915        0.521505
# 1  1916        0.424828
# 2  1917        0.425031
# 3  1918        0.477194
# 4  1919        0.828021

# %%
plt.figure(figsize=(10,6))
plt.title('Time Series of Mortality Rate')
sns.lineplot(x=data['Year'],y=data['Mortality Rate'],color='red')
plt.savefig('Time Series of Mortality Rate.png')
plt.show()
