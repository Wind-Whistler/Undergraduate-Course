# %% [markdown]
# # Homework 2

# %% [markdown]
# ## (a) 1. 证明
# （具体证明过程）

# %% [markdown]
# ## (a) 2. 作图

# %%
# 作图代码（并展示作图结果，这里略去）

# %% [markdown]
# ## (a) 3. 分析
#
# c1在十次迭代后cost相比最初，降低了50%；
#
# c2在十次迭代后cost相比最初，降低了60%；
#
# 两者的一些对比balabalabala
#
# （这只是一个格式的示例，没必要完全照着来，只是想展示一下分析部分应该有哪些要素。(b)题格式与(a)题一致，这里不再重复）
